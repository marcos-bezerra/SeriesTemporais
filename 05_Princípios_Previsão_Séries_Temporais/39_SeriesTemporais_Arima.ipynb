# %% [markdown]
# Arima não sazonal

# %%
from PIL import Image

# %%
Image.open('image/Arima.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=585x236 at 0x7FF59D910D60>

# %%
Image.open('image/Arima Nao Sazonal.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=645x186 at 0x7FF59C497640>

# %%
Image.open('image/Arima_ordem.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=373x267 at 0x7FF59DA102E0>

# %%
Image.open('image/Arima_p.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=658x278 at 0x7FF59DA106A0>

# %%
Image.open('image/Arima_ar.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=499x177 at 0x7FF59DA10E20>

# %%
Image.open('image/Arima_1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x125 at 0x7FF59DA10310>

# %%
Image.open('image/Arima_2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=636x313 at 0x7FF59DA10FD0>

# %%
Image.open('image/Arima_metrica.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=650x201 at 0x7FF59C4973D0>

# %%
Image.open('image/Arima_Processo.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=685x255 at 0x7FF59D9A1730>
