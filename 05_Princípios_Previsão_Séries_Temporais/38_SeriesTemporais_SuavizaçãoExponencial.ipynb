# %% [raw]
# Suavização Exponencial
#
# Princípio Básico
# . as observações passadas possuem pesos
# . quanto mais recentes as observações, maiores seus pesos para as previsões
# . utiliza médias que reduzem quanto mais distantes são as observações
# . o parâmetro alfa determina o índice de redução: valor entre 0 e 1
#     . próximo de 0: observações antigas tem maior peso
#     . próximo de 1: observações recentes tem mais peso

# %%
from PIL import Image
Image.open('image/SuavizacaoExponencial.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=618x274 at 0x7F84582C0070>

# %%
Image.open('image/SuavizacaoExponencialSimple.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=437x317 at 0x7F8458206850>

# %%
Image.open('image/TendênciaLinearHold.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=664x323 at 0x7F84582C0400>

# %%
Image.open('image/TendenciaAmortecida.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=614x238 at 0x7F84582ADE80>

# %%
Image.open('image/TendenciaAmortecidaxExponencial.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=652x317 at 0x7F84582AD790>

# %%
Image.open('image/Hold_WintersSazonal.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=515x210 at 0x7F84582AD940>

# %%
Image.open('image/Holt-WintersSazonal.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=676x281 at 0x7F84582AD490>

# %%
Image.open('image/ETS.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=598x311 at 0x7F84582ADEE0>
