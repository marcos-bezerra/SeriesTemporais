# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
data = pd.read_csv('/Users/marcos/Documents/00_Git_Projetos/SeriesTemporais/SeriesTemporais_Python/Download/Dados/AirPassengers.csv',
                   parse_dates=['Month'], index_col='Month') #, date_parser=dateparse)

# %%
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
d_log = np.log(data)
plt.plot(d_log)

# %%
plt.plot(data)

# %% [raw]
# . neste caso verificamos que não houve uma grande suavização com a aplicação do logaritmo
