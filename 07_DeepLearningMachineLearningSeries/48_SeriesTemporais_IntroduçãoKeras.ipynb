# %% [markdown]
# Keras
# API escrita sobre Theano, CNTK ou Tensorflow

# %%
from PIL import Image

# %%
Image.open("/Users/marcos/Documents/00_Git_Projetos/SeriesTemporais/SeriesTemporais_Python/Download/Dados/Estrutura Keras.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=486x287 at 0x7FEDCC5320D0>

# %%
Image.open("/Users/marcos/Documents/00_Git_Projetos/SeriesTemporais/SeriesTemporais_Python/Download/Dados/AdicionarCamadasKeras.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=652x290 at 0x7FEDCC61B970>

# %% [markdown]
# Instalando o Keras
#
# conda install -c anaconda keras
