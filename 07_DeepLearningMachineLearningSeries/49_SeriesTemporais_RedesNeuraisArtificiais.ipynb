# %%
from PIL import Image

# %%
Image.open("/Users/marcos/Documents/00_Git_Projetos/SeriesTemporais/SeriesTemporais_Python/Download/Dados/TopologiaRedesNeurais.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=664x298 at 0x7FEE803917C0>

# %%
Image.open("/Users/marcos/Documents/00_Git_Projetos/SeriesTemporais/SeriesTemporais_Python/Download/Dados/Epoch.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=426x287 at 0x7FEE8042A160>

# %%
Image.open("/Users/marcos/Documents/00_Git_Projetos/SeriesTemporais/SeriesTemporais_Python/Download/Dados/DeepLearning.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=573x315 at 0x7FEE80956D60>
